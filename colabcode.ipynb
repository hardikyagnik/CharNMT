# %%
# colabcode
# !pip install colabcode
# Out:
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.0.0-cp36-none-any.whl size=18781 sha256=393f3ef79e850559ac01e80d925fbe1d76deeaca28fe8fe2a3b3fa29e91bc950
#   Stored in directory: /root/.cache/pip/wheels/95/df/23/af8dde08c3fcdc7b966adcacef48ab29aa3b0b1860df5d2b79
# Successfully built pyngrok
# ...

# %%
# !colabcode --port 10000 --password cs583@hardik --mount_drive
# Out:
# --2020-12-16 02:57:45--  https://code-server.dev/install.sh
# Resolving code-server.dev (code-server.dev)... 172.67.214.225, 104.31.77.39, 104.31.76.39, ...
# Connecting to code-server.dev (code-server.dev)|172.67.214.225|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/cdr/code-server/master/install.sh [following]
# --2020-12-16 02:57:45--  https://raw.githubusercontent.com/cdr/code-server/master/install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13138 (13K) [text/plain]
# Saving to: ‘install.sh’
#
# install.sh          100%[===================>]  12.83K  --.-KB/s    in 0s
#
# 2020-12-16 02:57:45 (99.3 MB/s) - ‘install.sh’ saved [13138/13138]
#
# ...
